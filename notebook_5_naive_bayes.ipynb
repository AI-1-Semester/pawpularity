# %%
import pandas as pd
from sklearn.naive_bayes import GaussianNB
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
train_data = pd.read_csv("./data/train/train.csv")
test_data = pd.read_csv("./data/test/test.csv")
sample_submission = pd.read_csv("./data/test/sample_submission.csv")
train_data.head()
# Out:
#                                  Id  Subject Focus  Eyes  Face  Near  Action  \
# 0  0007de18844b0dbbb5e1f607da0606e0              0     1     1     1       0
# 1  0009c66b9439883ba2750fb825e1d7db              0     1     1     0       0
# 2  0013fd999caf9a3efe1352ca1b0d937e              0     1     1     1       0
# 3  0018df346ac9c1d8413cfcc888ca8246              0     1     1     1       0
# 4  001dc955e10590d3ca4673f034feeef2              0     0     0     1       0
#
#    Accessory  Group  Collage  Human  Occlusion  Info  Blur  Pawpularity
# 0          0      1        0      0          0     0     0           63
# 1          0      0        0      0          0     0     0           42
# 2          0      0        0      1          1     0     0           28
# 3          0      0        0      0          0     0     0           15
# 4          0      1        0      0          0     0     0           72

# %%
# Drop 'Id' and 'Pawpularity' columns from train data
if 'Id' in train_data.columns:
    train_data = train_data.drop('Id', axis=1)
if 'Pawpularity' in train_data.columns:
    train_data = train_data.drop('Pawpularity', axis=1)

# Drop 'Id' column from test data
if 'Id' in test_data.columns:
    test_data = test_data.drop('Id', axis=1)

# Filter the data where 'Human' = 1
filtered_train_data = train_data[train_data['Human'] == 1]
filtered_test_data = test_data[test_data['Human'] == 1]

# Split the data into features and target
X = filtered_train_data.drop('Occlusion', axis=1)
y = filtered_train_data['Occlusion']

# Create a Naive Bayes classifier
clf = GaussianNB()

# Train the classifier
clf.fit(X, y)

# Preprocess test data
X_test = filtered_test_data.drop('Occlusion', axis=1)

# Predict probabilities for the test data
y_prob = clf.predict_proba(X_test)

# Extract the probability of 'Occlusion'
occlusion_prob = y_prob[:, 1]  # Assuming 'Occlusion' is the second class

print(occlusion_prob)
# Out:
# [3.74732705e-15 6.62584761e-01]
